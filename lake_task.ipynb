# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'line':[1, 2, 5, 6, 1, 2, 2, 3, 0, 1, 5, 6,7,5,5,8,8,2]})
df.plot()
# Out:
# <AxesSubplot:>

# %%
df2 = pd.DataFrame({'line':[1, 2, 4, 2, 6, 7, 8, 3]})
df2.plot()
# Out:
# <AxesSubplot:>
